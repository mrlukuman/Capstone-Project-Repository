# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("databaseForStudents.csv")
df.head()
# Out:
#     ID  ID-folderName          name   patient   polyp gender   age  \
# 0  1.0            1.0  hikmet aydın  patient1  polyp1      M  53.0
# 1  NaN            NaN           NaN  patient1  polyp2    NaN   NaN
# 2  NaN            NaN           NaN  patient1  polyp3    NaN   NaN
# 3  2.0            2.0   şeref çolak  patient2  polyp1      M  49.0
# 4  NaN            NaN           NaN  patient2  polyp2    NaN   NaN
#
#      location diameter           type       subtype  Kİ67     braf PDL epitel  \
# 0  descending      NaN  nonneoplastic  hyperplastic  50.0  negatif    negatif
# 1  descending      NaN  nonneoplastic  hyperplastic  40.0  negatif    negatif
# 2  descending      9mm  nonneoplastic  hyperplastic  50.0  negatif    negatif
# 3   ascending     8 mm  nonneoplastic  hyperplastic  50.0  negatif    negatif
# 4  descending     7 mm     neoplastic       villous  60.0  negatif    negatif
#
#   PDL lenfos  vegf  cd34  cd34 skor   P53 Unnamed: 19
# ...

# %%
df = df.dropna()

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [ID, ID-folderName, name, patient, polyp, gender, age, location, diameter, type, subtype, Kİ67, braf, PDL epitel, PDL lenfos, vegf, cd34, cd34 skor, P53, Unnamed: 19]
# Index: []

# %% [markdown]
# ## From the above we know that all the rows contain some missing values that needs to be filled

# %%
df1 = pd.read_csv("databaseForStudents.csv")
df1.head()
# Out:
#     ID  ID-folderName          name   patient   polyp gender   age  \
# 0  1.0            1.0  hikmet aydın  patient1  polyp1      M  53.0
# 1  NaN            NaN           NaN  patient1  polyp2    NaN   NaN
# 2  NaN            NaN           NaN  patient1  polyp3    NaN   NaN
# 3  2.0            2.0   şeref çolak  patient2  polyp1      M  49.0
# 4  NaN            NaN           NaN  patient2  polyp2    NaN   NaN
#
#      location diameter           type       subtype  Kİ67     braf PDL epitel  \
# 0  descending      NaN  nonneoplastic  hyperplastic  50.0  negatif    negatif
# 1  descending      NaN  nonneoplastic  hyperplastic  40.0  negatif    negatif
# 2  descending      9mm  nonneoplastic  hyperplastic  50.0  negatif    negatif
# 3   ascending     8 mm  nonneoplastic  hyperplastic  50.0  negatif    negatif
# 4  descending     7 mm     neoplastic       villous  60.0  negatif    negatif
#
#   PDL lenfos  vegf  cd34  cd34 skor   P53 Unnamed: 19
# ...

# %% [markdown]
# ### Because I want to analyse the age-groups, I removed the extra rows with no names (ie. reapating rows for each patient)

# %%
df1_noname_dropped = df1.dropna(subset=["name"])
df1_noname_dropped.head()
# Out:
#     ID  ID-folderName            name   patient   polyp gender   age  \
# 0  1.0            1.0    hikmet aydın  patient1  polyp1      M  53.0
# 3  2.0            2.0     şeref çolak  patient2  polyp1      M  49.0
# 5  3.0            3.0       ali çoban  patient3  polyp1      M  70.0
# 6  4.0            4.0    atiye dursun  patient4  polyp1      F  57.0
# 7  5.0            5.0  keziban fındık  patient5  polyp1      F  65.0
#
#      location diameter           type       subtype  Kİ67     braf PDL epitel  \
# 0  descending      NaN  nonneoplastic  hyperplastic  50.0  negatif    negatif
# 3   ascending     8 mm  nonneoplastic  hyperplastic  50.0  negatif    negatif
# 5   ascending      5mm  nonneoplastic   nonspesifik  10.0  negatif    negatif
# 6     sigmoid      8mm  nonneoplastic  hyperplastic  30.0  negatif    negatif
# 7   ascending      NaN  nonneoplastic   nonspesifik  15.0  negatif    negatif
#
#   PDL lenfos  vegf  cd34  cd34 skor   P53 Unnamed: 19
# ...

# %%
df2_Age = df1_noname_dropped[["ID", "name", "gender","age", "type", "subtype"]]

# %%
df2_Age.head()
# Out:
#     ID            name gender   age           type       subtype
# 0  1.0    hikmet aydın      M  53.0  nonneoplastic  hyperplastic
# 3  2.0     şeref çolak      M  49.0  nonneoplastic  hyperplastic
# 5  3.0       ali çoban      M  70.0  nonneoplastic   nonspesifik
# 6  4.0    atiye dursun      F  57.0  nonneoplastic  hyperplastic
# 7  5.0  keziban fındık      F  65.0  nonneoplastic   nonspesifik
