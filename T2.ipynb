# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('ihc-type-correlation.csv')
df.head(10)
# Out:
#    Ki67      braf PDL epitel PDL lenfos  vegf  cd34  cd34 score  P53  \
# 0    50  Negative   Negative   Negative    20    47           2   15
# 1    40  Negative   Negative   Negative    30    39           2   10
# 2    50  Negative   Negative   Negative    50    50           3   20
# 3    50  Negative   Negative       Weak    40    63           3    5
# 4    60  Negative   Negative       Weak    70    57           2   25
# 5    10  Negative   Negative   Negative    40    70           3    2
# 6    30  Negative   Negative       Weak    75    50           2   25
# 7    15  Negative   Negative   Negative     0    55           2    5
# 8    10  Negative   Negative   Negative     0    34           1    5
# 9     5  Negative   Negative       Weak    20    45           2    3
#
#             type       subtype
# 0  nonneoplastic  hyperplastic
# 1  nonneoplastic  hyperplastic
# 2  nonneoplastic  hyperplastic
# 3  nonneoplastic  hyperplastic
# 4     neoplastic       villous
# ...

# %%
df.plot(kind='scatter',x='type',y='Ki67') # scatter plot
# Out:
# <AxesSubplot:xlabel='type', ylabel='Ki67'>

# %%
df.plot(kind='scatter',x='type',y='vegf') # scatter plot
# Out:
# <AxesSubplot:xlabel='type', ylabel='vegf'>

# %%
df.plot(kind='scatter',x='type',y='cd34') # scatter plot
# Out:
# <AxesSubplot:xlabel='type', ylabel='cd34'>

# %%
df.plot(kind='scatter',x='type',y='cd34 score') # scatter plot

cdscore_counts = df["cd34 score"].value_counts()
cdscore_counts.plot(kind='bar', xlabel="Count", ylabel="score")
# Out:
# <AxesSubplot:xlabel='Count', ylabel='score'>

# %%
df.plot(kind='scatter',x='type',y='P53') # scatter plot
# Out:
# <AxesSubplot:xlabel='type', ylabel='P53'>

# %%
df.plot(kind='scatter',x='type',y= ('Ki67','P53')) # scatter plot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Ki67', 'P53')
#
# ...
